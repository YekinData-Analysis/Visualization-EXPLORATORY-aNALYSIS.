# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

#we importing all the necessary data

# %%
#reading the each Dataset

df_cust=pd.read_csv(r'C:\\Users\\HP\Downloads\archive (30)\olist_customers_dataset.csv')
df_geo=pd.read_csv(r'C:\\Users\\HP\Downloads\archive (30)\olist_geolocation_dataset.csv')
df_ord=pd.read_csv(r'C:\\Users\\HP\Downloads\archive (30)\olist_customers_dataset.csv')
df_pay=pd.read_csv(r'C:\\Users\\HP\Downloads\archive (30)\olist_order_payments_dataset.csv')
df_rev=pd.read_csv(r'C:\\Users\\HP\Downloads\archive (30)\olist_order_reviews_dataset.csv')
df_ord2=pd.read_csv(r'C:\\Users\\HP\Downloads\archive (30)\olist_orders_dataset.csv')
df_prod=pd.read_csv(r'C:\\Users\\HP\Downloads\archive (30)\olist_products_dataset.csv')
df_sell=pd.read_csv(r'C:\\Users\\HP\Downloads\archive (30)\olist_sellers_dataset.csv')

# %%
#Creating each variable for each data
#we have Customer data


df_cust=df_cust.reset_index()

df_cust
# Out:
#        index                       customer_id  \
# 0          0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1          1  18955e83d337fd6b2def6b18a428ac77
# 2          2  4e7b3e00288586ebd08712fdd0374a03
# 3          3  b2b6027bc5c5109e529d4dc6358b12c3
# 4          4  4f2d8ab171c80ec8364f7c12e35b23ad
# ...      ...                               ...
# 99436  99436  17ddf5dd5d51696bb3d7c6291687be6f
# 99437  99437  e7b71a9017aa05c9a7fd292d714858e8
# 99438  99438  5e28dfe12db7fb50a4b2f691faecea5e
# 99439  99439  56b18e2166679b8a959d72dd06da27f9
# 99440  99440  274fa6071e5e17fe303b9748641082c8
#
#                      customer_unique_id  customer_zip_code_prefix  \
# 0      861eff4711a542e4b93843c6dd7febb0                     14409
# 1      290c77bc529b7ac935b93aa66c333dc3                      9790
# 2      060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3      259dac757896d24d7702b9acbbff3f3c                      8775
# ...

# %% [markdown]
# the df_cust dataframe contains 99441 rows and 6 columns. The columns are level_0, index, customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, and customer_state. The type of each column is int64 (level_0 and index), object (customer_id, customer_unique_id, customer_city, and customer_state), and int64 (customer_zip_code_prefix). The index is False. The count for each column is 99441, with the exception of customer_unique_id which has a count of 96096.

# %%
#varaible name for data doe location

df_geo
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %% [markdown]
# The dataset df_geo contains 1,000,163 rows and 5 columns. The index column is an integer type and is not an index. The geolocation_zip_code_prefix column is an integer type with 19,015 unique values ranging from 1001 to 99990.

# %%
#creating a Varaible name for orderID for custumer Table

df_ord=df_ord.reset_index()

df_ord
# Out:
#        index                       customer_id  \
# 0          0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1          1  18955e83d337fd6b2def6b18a428ac77
# 2          2  4e7b3e00288586ebd08712fdd0374a03
# 3          3  b2b6027bc5c5109e529d4dc6358b12c3
# 4          4  4f2d8ab171c80ec8364f7c12e35b23ad
# ...      ...                               ...
# 99436  99436  17ddf5dd5d51696bb3d7c6291687be6f
# 99437  99437  e7b71a9017aa05c9a7fd292d714858e8
# 99438  99438  5e28dfe12db7fb50a4b2f691faecea5e
# 99439  99439  56b18e2166679b8a959d72dd06da27f9
# 99440  99440  274fa6071e5e17fe303b9748641082c8
#
#                      customer_unique_id  customer_zip_code_prefix  \
# 0      861eff4711a542e4b93843c6dd7febb0                     14409
# 1      290c77bc529b7ac935b93aa66c333dc3                      9790
# 2      060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3      259dac757896d24d7702b9acbbff3f3c                      8775
# ...

# %% [markdown]
# df_ord is a pandas dataframe containing 99441 rows and 6 columns. The columns are 'level_0', 'index', 'customer_id', 'customer_unique_id', 'customer_zip_code_prefix', and 'customer_city'. The 'level_0' and 'index' columns are both int64 data types and contain the same values, ranging from 0 to 99440. The 'customer_id' column is an object data type and contains 99441 unique values.

# %%
#creating a variable name for order table 

df_ord2=df_ord2.reset_index()

df_ord2
# Out:
#        index                          order_id  \
# 0          0  e481f51cbdc54678b7cc49136f2d6af7
# 1          1  53cdb2fc8bc7dce0b6741e2150273451
# 2          2  47770eb9100c2d0c44946d9cf07ec65d
# 3          3  949d5b44dbf5de918fe9c16f97b45f8a
# 4          4  ad21c59c0840e6cb83a9ceb5573f8159
# ...      ...                               ...
# 99436  99436  9c5dedf39a927c1b2549525ed64a053c
# 99437  99437  63943bddc261676b46f01ca7ac2f7bd8
# 99438  99438  83c1379a015df1e13d02aae0204711ab
# 99439  99439  11c177c8e97725db2631073c19f07b62
# 99440  99440  66dea50a8b16d9b4dee7af250b4be1a5
#
#                             customer_id order_status order_purchase_timestamp  \
# 0      9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 1      b0830fb4747a6c6d20dea0b8c802d7ef    delivered      2018-07-24 20:41:37
# 2      41ce2a54c0b03bf3443c3d931a367089    delivered      2018-08-08 08:38:49
# 3      f88197465ea7920adcdbec7375364d82    delivered      2017-11-18 19:28:06
# ...

# %% [markdown]
# df_ord2 is a pandas dataframe with 99441 rows and 8 columns. The columns are level_0, index, order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date and order_estimated_delivery_date. The column types are int64, object and datetime.

# %%
#merging the two tbl together to give us a whole full table

dff=df_ord.merge(df_ord2,on='index')

dff
# Out:
#        index                     customer_id_x  \
# 0          0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1          1  18955e83d337fd6b2def6b18a428ac77
# 2          2  4e7b3e00288586ebd08712fdd0374a03
# 3          3  b2b6027bc5c5109e529d4dc6358b12c3
# 4          4  4f2d8ab171c80ec8364f7c12e35b23ad
# ...      ...                               ...
# 99436  99436  17ddf5dd5d51696bb3d7c6291687be6f
# 99437  99437  e7b71a9017aa05c9a7fd292d714858e8
# 99438  99438  5e28dfe12db7fb50a4b2f691faecea5e
# 99439  99439  56b18e2166679b8a959d72dd06da27f9
# 99440  99440  274fa6071e5e17fe303b9748641082c8
#
#                      customer_unique_id  customer_zip_code_prefix  \
# 0      861eff4711a542e4b93843c6dd7febb0                     14409
# 1      290c77bc529b7ac935b93aa66c333dc3                      9790
# 2      060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3      259dac757896d24d7702b9acbbff3f3c                      8775
# ...

# %%
#since they Are made of up of the same rows and custumerId 

df=df_cust.merge(dff,on='index')

df.head()
# Out:
#    index                       customer_id              customer_unique_id_x  \
# 0      0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix_x        customer_city_x customer_state_x  \
# 0                       14409                 franca               SP
# 1                        9790  sao bernardo do campo               SP
# 2                        1151              sao paulo               SP
# 3                        8775        mogi das cruzes               SP
# 4                       13056               campinas               SP
#
#                       customer_id_x              customer_unique_id_y  \
# ...

# %% [markdown]
# we merge The custumer table,order table and Lastly the order table2 together which give us a full result of df

# %%
#we Split the TIme from th date

df[['Order_Date_Purchase','Order_Time_Purchase']]=df['order_purchase_timestamp'].str.split(' ',expand=True)

# %%
# so as this one,we split the time from the Date


df[['Order_App_Date','Order_App_Time']]=df['order_approved_at'].str.split(' ',expand=True)

# %%
df.head()
# Out:
#    index                       customer_id              customer_unique_id_x  \
# 0      0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix_x        customer_city_x customer_state_x  \
# 0                       14409                 franca               SP
# 1                        9790  sao bernardo do campo               SP
# 2                        1151              sao paulo               SP
# 3                        8775        mogi das cruzes               SP
# 4                       13056               campinas               SP
#
#                       customer_id_x              customer_unique_id_y  \
# ...

# %% [markdown]
# >Now e have a full dataset.

# %%
#we drop the previous columns we spitte already


df=df.drop(['order_purchase_timestamp','order_approved_at'],axis=1)

df.head()
# Out:
#    index                       customer_id              customer_unique_id_x  \
# 0      0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix_x        customer_city_x customer_state_x  \
# 0                       14409                 franca               SP
# 1                        9790  sao bernardo do campo               SP
# 2                        1151              sao paulo               SP
# 3                        8775        mogi das cruzes               SP
# 4                       13056               campinas               SP
#
#                       customer_id_x              customer_unique_id_y  \
# ...

# %%
#we Also splited the order_delivered_date

df[['Order_Deliever_Date','Order_Deliever_Time']]=df['order_delivered_carrier_date'].str.split(' ',expand=True)

# %%
#The same as here We Splitted the date

df[['Order_Deliever_Date','Order_Deliever_Time']]=df['order_delivered_customer_date'].str.split(' ',expand=True)
df[['Order_carrier_Date','Order_Carrier_Time']]=df['order_delivered_carrier_date'].str.split(' ',expand=True)

# %%
df.head()
# Out:
#    index                       customer_id              customer_unique_id_x  \
# 0      0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix_x        customer_city_x customer_state_x  \
# 0                       14409                 franca               SP
# 1                        9790  sao bernardo do campo               SP
# 2                        1151              sao paulo               SP
# 3                        8775        mogi das cruzes               SP
# 4                       13056               campinas               SP
#
#                       customer_id_x              customer_unique_id_y  \
# ...

# %%
#we also splitted The date from time

df[['Date_Estimated_Delivery','Time_Estimated_Delivery']]=df['order_estimated_delivery_date'].str.split(' ',expand=True)

# %%
df.head()
# Out:
#    index                       customer_id              customer_unique_id_x  \
# 0      0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix_x        customer_city_x customer_state_x  \
# 0                       14409                 franca               SP
# 1                        9790  sao bernardo do campo               SP
# 2                        1151              sao paulo               SP
# 3                        8775        mogi das cruzes               SP
# 4                       13056               campinas               SP
#
#                       customer_id_x              customer_unique_id_y  \
# ...

# %%
#getting it to display the full names of the columns

pd.set_option('display.max_columns',27)

# %%
df.head()
# Out:
#    index                       customer_id              customer_unique_id_x  \
# 0      0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix_x        customer_city_x customer_state_x  \
# 0                       14409                 franca               SP
# 1                        9790  sao bernardo do campo               SP
# 2                        1151              sao paulo               SP
# 3                        8775        mogi das cruzes               SP
# 4                       13056               campinas               SP
#
#                       customer_id_x              customer_unique_id_y  \
# ...

# %%
#deleting the unnecessary columns

df=df.drop(['order_delivered_carrier_date','order_delivered_customer_date','order_estimated_delivery_date','Time_Estimated_Delivery'],axis=1)

# %%
df.head()
# Out:
#    index                       customer_id              customer_unique_id_x  \
# 0      0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix_x        customer_city_x customer_state_x  \
# 0                       14409                 franca               SP
# 1                        9790  sao bernardo do campo               SP
# 2                        1151              sao paulo               SP
# 3                        8775        mogi das cruzes               SP
# 4                       13056               campinas               SP
#
#                       customer_id_x              customer_unique_id_y  \
# ...

# %%
#Dropping the unnecesary columns

df=df.drop(['customer_id_x','customer_unique_id_y','index'],axis=1)

df.head()
# Out:
#                         customer_id              customer_unique_id_x  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix_x        customer_city_x customer_state_x  \
# 0                       14409                 franca               SP
# 1                        9790  sao bernardo do campo               SP
# 2                        1151              sao paulo               SP
# 3                        8775        mogi das cruzes               SP
# 4                       13056               campinas               SP
#
#    customer_zip_code_prefix_y        customer_city_y customer_state_y  \
# ...

# %%
pd.DatetimeIndex(df['Order_Date_Purchase']).year.unique()
# Out:
# Int64Index([2017, 2018, 2016], dtype='int64', name='Order_Date_Purchase')

# %% [markdown]
# >The Dataset is made of year of 2016 - 2018 olist transaction Detail.

# %%
#dropping the unecessary columns

df['order_status'].value_counts()
# Out:
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_status, dtype: int64

# %% [markdown]
# About 96 thousand plus of Goods ave been delivered.
#
# Shipped 1107 Goods
#
# and order purchase cancel are about 625 and unavalibale goods are 609.
#
# processing Goods are about 301.

# %%
#Let check the Approved goods 

df.query('order_status=="approved"')
# Out:
#                             customer_id              customer_unique_id_x  \
# 44897  db29e72564815db5aa89037daf547c81  e7074f297dd4e0a17f2cc685a0b55ce5
# 88457  8c9f9f3fa188674e6d52e4ee94fb0c07  70d27d9eb0678a4ddd8b3d5b0cf40d96
#
#        customer_zip_code_prefix_x customer_city_x customer_state_x  \
# 44897                       88135         palhoca               SC
# 88457                       58052     joao pessoa               PB
#
#        customer_zip_code_prefix_y customer_city_y customer_state_y  \
# 44897                       88135         palhoca               SC
# 88457                       58052     joao pessoa               PB
#
#                                order_id                     customer_id_y  \
# 44897  a2e4c44360b4a57bdff22f3a4630c173  8886130db0ea6e9e70ba0b03d7c0d286
# 88457  132f1e724165a07f6362532bfb97486e  b2191912d8ad6eac2e4dc3b6e1459515
#
#       order_status Order_Date_Purchase Order_Time_Purchase Order_App_Date  \
# ...

# %%
df.query('order_status=="created"')
# Out:
#                             customer_id              customer_unique_id_x  \
# 7434   05af4522d26d0a46926e0337ef153dd9  320423d439b0210433a4e3885a0eb3af
# 9238   ebfeafbe3a7a9bd5247da19ab28eae2f  2e0b9ebd84e24a4ea2fb386a3a1a7a15
# 21441  fa3946634ae6b04238d501a3f9d7dd80  8033b326df991ace634ac72bd3a02fb5
# 55086  58be67590e18c3d1e7d611dc65eda107  0dbe45fa08f724bd664f996960b71a82
# 58958  27b939024664f89f9ed6d687e1265de0  487e9e85b88b68f2fb0a84d0296936f6
#
#        customer_zip_code_prefix_x customer_city_x customer_state_x  \
# 7434                        11040          santos               SP
# 9238                        74080         goiania               GO
# 21441                        5367       sao paulo               SP
# 55086                       28570        itaocara               RJ
# 58958                       24940          marica               RJ
#
#        customer_zip_code_prefix_y customer_city_y customer_state_y  \
# ...

# %%
#checking the data type

type(df['Order_App_Date'][0])
# Out:
# str

# %%
#converting from str to date columns

df['Order_App_Date']=pd.to_datetime(df['Order_App_Date'])
df['Order_Date_Puchase']=pd.to_datetime(df['Order_Date_Purchase'])
df['Order_Deliever_Date']=pd.to_datetime(df['Order_Deliever_Date'])
df['Order_carrier_Date']=pd.to_datetime(df['Order_carrier_Date'])

# %%
#checking the data info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 99441 non-null  object
#  1   customer_unique_id_x        99441 non-null  object
#  2   customer_zip_code_prefix_x  99441 non-null  int64
#  3   customer_city_x             99441 non-null  object
#  4   customer_state_x            99441 non-null  object
#  5   customer_zip_code_prefix_y  99441 non-null  int64
#  6   customer_city_y             99441 non-null  object
#  7   customer_state_y            99441 non-null  object
#  8   order_id                    99441 non-null  object
#  9   customer_id_y               99441 non-null  object
#  10  order_status                99441 non-null  object
#  11  Order_Date_Purchase         99441 non-null  object
#  12  Order_Time_Purchase         99441 non-null  object
# ...

# %%
#Checking

df['Order_Date_Puchase']=pd.to_datetime(df['Order_Date_Puchase'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 99441 non-null  object
#  1   customer_unique_id_x        99441 non-null  object
#  2   customer_zip_code_prefix_x  99441 non-null  int64
#  3   customer_city_x             99441 non-null  object
#  4   customer_state_x            99441 non-null  object
#  5   customer_zip_code_prefix_y  99441 non-null  int64
#  6   customer_city_y             99441 non-null  object
#  7   customer_state_y            99441 non-null  object
#  8   order_id                    99441 non-null  object
#  9   customer_id_y               99441 non-null  object
#  10  order_status                99441 non-null  object
#  11  Order_Date_Purchase         99441 non-null  object
#  12  Order_Time_Purchase         99441 non-null  object
# ...

# %%
#checking the format

df['Order_App_Date']=pd.to_datetime(df['Order_App_Date'],infer_datetime_format=True)

# %%
df['Order_App_Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 99441 entries, 0 to 99440
# Series name: Order_App_Date
# Non-Null Count  Dtype
# --------------  -----
# 99281 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 3.5 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 99441 non-null  object
#  1   customer_unique_id_x        99441 non-null  object
#  2   customer_zip_code_prefix_x  99441 non-null  int64
#  3   customer_city_x             99441 non-null  object
#  4   customer_state_x            99441 non-null  object
#  5   customer_zip_code_prefix_y  99441 non-null  int64
#  6   customer_city_y             99441 non-null  object
#  7   customer_state_y            99441 non-null  object
#  8   order_id                    99441 non-null  object
#  9   customer_id_y               99441 non-null  object
#  10  order_status                99441 non-null  object
#  11  Order_Date_Purchase         99441 non-null  object
#  12  Order_Time_Purchase         99441 non-null  object
# ...

# %%
#converting 

df['Order_App_Date']=pd.to_datetime(df['Order_App_Date'],errors='coerce',infer_datetime_format=True)

# %%
#but giving me object date object instead of date format

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 99441 non-null  object
#  1   customer_unique_id_x        99441 non-null  object
#  2   customer_zip_code_prefix_x  99441 non-null  int64
#  3   customer_city_x             99441 non-null  object
#  4   customer_state_x            99441 non-null  object
#  5   customer_zip_code_prefix_y  99441 non-null  int64
#  6   customer_city_y             99441 non-null  object
#  7   customer_state_y            99441 non-null  object
#  8   order_id                    99441 non-null  object
#  9   customer_id_y               99441 non-null  object
#  10  order_status                99441 non-null  object
#  11  Order_Date_Purchase         99441 non-null  object
#  12  Order_Time_Purchase         99441 non-null  object
# ...

# %%
df.head()
# Out:
#                         customer_id              customer_unique_id_x  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix_x        customer_city_x customer_state_x  \
# 0                       14409                 franca               SP
# 1                        9790  sao bernardo do campo               SP
# 2                        1151              sao paulo               SP
# 3                        8775        mogi das cruzes               SP
# 4                       13056               campinas               SP
#
#    customer_zip_code_prefix_y        customer_city_y customer_state_y  \
# ...

# %%
type(df['Order_App_Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(df['Order_Date_Puchase'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#Order date vs Order approval Date, This xplain, why we have more delay in the Approval of items been purchase.

df['Days_Used_Process_Approval']=pd.DatetimeIndex(df['Order_Date_Puchase']).day-pd.DatetimeIndex(df['Order_App_Date']).day

# %%
df['Days_Used_Process_Approval']
# Out:
# 0        0.0
# 1       -2.0
# 2        0.0
# 3        0.0
# 4        0.0
#         ...
# 99436    0.0
# 99437    0.0
# 99438    0.0
# 99439    0.0
# 99440   -1.0
# Name: Days_Used_Process_Approval, Length: 99441, dtype: float64

# %%
df['Days_Used_Process_Approval'].unique()
# Out:
# array([  0.,  -2.,  -5.,  -1.,  29.,  -4.,  28.,  -3.,  26.,  27.,  30.,
#         nan,  25.,  24., -11.,  -6.,  23.,  -8.,  21., -12.,   6.,  -7.,
#         17.,  22.,  18., -10., -13.,  20.,   1.,  19.,  -9., -17., -23.])

# %% [markdown]
# >As We can see we gat days before an item to be approve!
# why some purchased goods Take Days to approve while some take days to be approve ,
#
# this shouldn't be so.

# %%
df['Days_Used_Process_Approval'].value_counts()
# Out:
#  0.0     68733
# -1.0     16562
# -2.0      8644
# -3.0      2058
# -4.0      1239
#  29.0      545
#  30.0      290
#  27.0      270
# -5.0       261
#  28.0      246
#  26.0      205
#  25.0       68
# -6.0        35
# -7.0        24
#  24.0       22
# -8.0        14
# -12.0       13
#  23.0       10
# -11.0        9
#  22.0        6
#  19.0        4
# -9.0         4
#  21.0        3
#  17.0        3
# -10.0        3
#  18.0        2
# -13.0        2
# -23.0        2
#  6.0         1
#  20.0        1
#  1.0         1
# -17.0        1
# Name: Days_Used_Process_Approval, dtype: int64

# %%
df['Days_Used_Process_Carrier']=pd.DatetimeIndex(df['Order_App_Date']).day-pd.DatetimeIndex(df['Order_carrier_Date']).day

# %%
#checking for days used In processing The carrier 

df['Days_Used_Process_Carrier']
# Out:
# 0       -2.0
# 1        0.0
# 2        0.0
# 3       -4.0
# 4       -1.0
#         ...
# 99436   -1.0
# 99437   -1.0
# 99438   -1.0
# 99439   -4.0
# 99440    0.0
# Name: Days_Used_Process_Carrier, Length: 99441, dtype: float64

# %%
df['Days_Used_Process_Carrier'].value_counts()
# Out:
# -1.0     27839
# -2.0     15979
#  0.0     15199
# -3.0     11170
# -4.0      6850
#          ...
# -23.0       15
# -30.0       13
# -29.0       12
# -26.0        5
# -28.0        2
# Name: Days_Used_Process_Carrier, Length: 61, dtype: int64

# %% [markdown]
# >Waoh, The days used in processing the carrier sometimes takes 28 approxiamtely a Month for carrier after Approval.
#
# The comapny need to do better in this Aspect.

# %%
df['Days_Used_Process_Delivery']=pd.DatetimeIndex(df['Order_carrier_Date']).day-pd.DatetimeIndex(df['Order_Deliever_Date']).day

# %% [markdown]
# even after carrier Services, the Delivery department days for delivery is maximum is 3 days after the carriers phase, the the delivery department take used about a month.

# %%
df['Days_Used_Process_Delivery'].value_counts()
# Out:
# -1.0     7989
# -6.0     7462
# -7.0     7332
# -5.0     6537
# -3.0     6497
#          ...
# -26.0      67
# -27.0      29
# -28.0      20
# -29.0       7
# -30.0       1
# Name: Days_Used_Process_Delivery, Length: 61, dtype: int64

# %%
df.head()
# Out:
#                         customer_id              customer_unique_id_x  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix_x        customer_city_x customer_state_x  \
# 0                       14409                 franca               SP
# 1                        9790  sao bernardo do campo               SP
# 2                        1151              sao paulo               SP
# 3                        8775        mogi das cruzes               SP
# 4                       13056               campinas               SP
#
#    customer_zip_code_prefix_y        customer_city_y customer_state_y  \
# ...

# %%
#City with the Most supplys

df['customer_city_x'].value_counts()
# Out:
# sao paulo            15540
# rio de janeiro        6882
# belo horizonte        2773
# brasilia              2131
# curitiba              1521
#                      ...
# bequimao                 1
# andarai                  1
# vargem grande            1
# curvelandia              1
# eugenio de castro        1
# Name: customer_city_x, Length: 4119, dtype: int64

# %% [markdown]
# >it Save to say SAO PAULO State is The Home Base Of the OLIST COMMERCE COMPANY.

# %%
df_pay
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
df_prod
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df_pay=df_pay.reset_index()

df_pay
# Out:
#          index                          order_id  payment_sequential  \
# 0            0  b81ef226f3fe1789b1e8b2acac839d17                   1
# 1            1  a9810da82917af2d9aefd1278f1dcfa0                   1
# 2            2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1
# 3            3  ba78997921bbcdc1373bb41e913ab953                   1
# 4            4  42fdf880ba16b47b59251dd489d4441a                   1
# ...        ...                               ...                 ...
# 103881  103881  0406037ad97740d563a178ecc7a2075c                   1
# 103882  103882  7b905861d7c825891d6347454ea7863f                   1
# 103883  103883  32609bbb3dd69b3c066a6860554a77bf                   1
# 103884  103884  b8b61059626efa996a60be9bb9320e10                   1
# 103885  103885  28bbae6599b09d39ca406b747b6632b1                   1
#
#        payment_type  payment_installments  payment_value
# 0       credit_card                     8          99.33
# ...

# %%
df_prod=df_prod.reset_index()

df_prod
# Out:
#        index                        product_id  \
# 0          0  1e9e8ef04dbcff4541ed26657ea517e5
# 1          1  3aa071139cb16b67ca9e5dea641aaa2f
# 2          2  96bd76ec8810374ed1b65e291975717f
# 3          3  cef67bcfe19066a932b7673e239eb23d
# 4          4  9dc1a7de274444849c219cff195d0b71
# ...      ...                               ...
# 32946  32946  a0b7d5a992ccda646f2d34e418fff5a0
# 32947  32947  bf4538d88321d0fd4412a93c974510e6
# 32948  32948  9a7c6041fa9592d9d9ef6cfe62a71f8c
# 32949  32949  83808703fc0706a22e264b9d75f04a2e
# 32950  32950  106392145fca363410d287a815be6de4
#
#                    product_category_name  product_name_lenght  \
# 0                             perfumaria                 40.0
# 1                                  artes                 44.0
# 2                          esporte_lazer                 46.0
# 3                                  bebes                 27.0
# 4                  utilidades_domesticas                 37.0
# ...

# %%
ndf=df_prod.merge(df_pay,on='index')


ndf.head()
# Out:
#    index                        product_id  product_category_name  \
# 0      0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1      1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2      2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3      3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4      4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# ...

# %% [markdown]
# >Before deleting some columne can we assume that in product_descriptioon_Lenght, the product desciption lenght that as the most highgest figures is the most function or valueable functions.
#
# so let plot it out .

# %%
#counting

ndf['product_description_lenght'].value_counts().to_frame().sort_index(ascending=False)
# Out:
#         product_description_lenght
# 3992.0                           1
# 3988.0                           1
# 3985.0                           1
# 3976.0                           1
# 3963.0                           1
# ...                            ...
# 23.0                             1
# 20.0                             1
# 15.0                             1
# 8.0                              1
# 4.0                              5
#
# [2960 rows x 1 columns]

# %%
ndf.query('product_description_lenght==3992')
# Out:
#        index                        product_id product_category_name  \
# 31404  31404  47d52bb24ef8a3aa09724f00604be3ba          dvds_blu_ray
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 31404                 30.0                      3992.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 31404            2600.0               41.0               11.0
#
#        product_width_cm                          order_id  payment_sequential  \
# 31404              32.0  c393997142861148ab156520bb0ed1fb                   1
#
#       payment_type  payment_installments  payment_value Price_Scores
# 31404  credit_card                     3         168.96         Lows

# %%
ndf['payment_value'].max()
# Out:
# 4764.34

# %%
ndf.query('payment_value==4764.34')
# Out:
#       index                        product_id product_category_name  \
# 6440   6440  bb9a7bcdb8c9facc7f1262db27fb1300          beleza_saude
#
#       product_name_lenght  product_description_lenght  product_photos_qty  \
# 6440                 30.0                       548.0                 1.0
#
#       product_weight_g  product_length_cm  product_height_cm  \
# 6440             150.0               16.0                5.0
#
#       product_width_cm                          order_id  payment_sequential  \
# 6440              17.0  199af31afc78c699f0dbf71fb178d4d4                   1
#
#      payment_type  payment_installments  payment_value Price_Scores
# 6440  credit_card                     8        4764.34         High

# %% [markdown]
# >Unfortunately it not

# %%
ndf['product_category_name'].value_counts()
# Out:
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_category_name, Length: 73, dtype: int64

# %%
#let get the pproduct function

came_df=ndf.query('product_category_name=="cama_mesa_banho"')

# %%
came_df['payment_sequential'].value_counts()
# Out:
# 1     2899
# 2       90
# 3       16
# 4        6
# 10       5
# 11       3
# 7        2
# 5        2
# 9        2
# 8        2
# 6        1
# 16       1
# Name: payment_sequential, dtype: int64

# %% [markdown]
# The Product name called 'cama_mesa_banho' is the most sells product that bring more income to the company.
# which have make most of the custumers to pay onces or twices majorly.

# %%
ndf['payment_value'].plot.box(vert=False)
# Out:
# <AxesSubplot:>

# %%
#now let categorise the price by the Sub product

ndf['Price_Scores']=pd.cut(x=ndf['payment_value'],bins=[-np.infty,1000,3000,np.infty],labels=['Lows','Regular','High'])

# %%
ndf['Price_Scores'].value_counts()
# Out:
# Lows       32573
# Regular      368
# High          10
# Name: Price_Scores, dtype: int64

# %% [markdown]
# That is majority of the company goods are more of low prices

# %%
ndf
# Out:
#        index                        product_id  \
# 0          0  1e9e8ef04dbcff4541ed26657ea517e5
# 1          1  3aa071139cb16b67ca9e5dea641aaa2f
# 2          2  96bd76ec8810374ed1b65e291975717f
# 3          3  cef67bcfe19066a932b7673e239eb23d
# 4          4  9dc1a7de274444849c219cff195d0b71
# ...      ...                               ...
# 32946  32946  a0b7d5a992ccda646f2d34e418fff5a0
# 32947  32947  bf4538d88321d0fd4412a93c974510e6
# 32948  32948  9a7c6041fa9592d9d9ef6cfe62a71f8c
# 32949  32949  83808703fc0706a22e264b9d75f04a2e
# 32950  32950  106392145fca363410d287a815be6de4
#
#                    product_category_name  product_name_lenght  \
# 0                             perfumaria                 40.0
# 1                                  artes                 44.0
# 2                          esporte_lazer                 46.0
# 3                                  bebes                 27.0
# 4                  utilidades_domesticas                 37.0
# ...

# %%
#let the goods that have hight install ment ???

ndf.query('payment_installments==24')
# Out:
#        index                        product_id   product_category_name  \
# 2970    2970  97c57b8428f6b7a7597248a02938681d       moveis_escritorio
# 10791  10791  1cf4209f5358de32c5cae2c2dbb84aed               telefonia
# 12307  12307  eaaedcf6f1fee559b27b286e16afdf88  informatica_acessorios
# 18512  18512  20e5127b0dda6370dd7795b2952da13a        moveis_decoracao
# 21713  21713  b343cce43d6f08fe602d2892b106ad59       moveis_escritorio
# 23024  23024  85b8a24337b4e2571f8fee38f4253a06           esporte_lazer
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 2970                  51.0                      2250.0                 1.0
# 10791                 54.0                       596.0                 2.0
# 12307                 43.0                      1300.0                 4.0
# 18512                 58.0                      2043.0                 4.0
# 21713                 55.0                       569.0                 1.0
# ...

# %%
df_ord2
# Out:
#        index                          order_id  \
# 0          0  e481f51cbdc54678b7cc49136f2d6af7
# 1          1  53cdb2fc8bc7dce0b6741e2150273451
# 2          2  47770eb9100c2d0c44946d9cf07ec65d
# 3          3  949d5b44dbf5de918fe9c16f97b45f8a
# 4          4  ad21c59c0840e6cb83a9ceb5573f8159
# ...      ...                               ...
# 99436  99436  9c5dedf39a927c1b2549525ed64a053c
# 99437  99437  63943bddc261676b46f01ca7ac2f7bd8
# 99438  99438  83c1379a015df1e13d02aae0204711ab
# 99439  99439  11c177c8e97725db2631073c19f07b62
# 99440  99440  66dea50a8b16d9b4dee7af250b4be1a5
#
#                             customer_id order_status order_purchase_timestamp  \
# 0      9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 1      b0830fb4747a6c6d20dea0b8c802d7ef    delivered      2018-07-24 20:41:37
# 2      41ce2a54c0b03bf3443c3d931a367089    delivered      2018-08-08 08:38:49
# 3      f88197465ea7920adcdbec7375364d82    delivered      2017-11-18 19:28:06
# ...

# %%
dframe=df.loc[:,['Order_Date_Purchase','order_id','customer_id']]

# %%
dframe
# Out:
#       Order_Date_Purchase                          order_id  \
# 0              2017-10-02  e481f51cbdc54678b7cc49136f2d6af7
# 1              2018-07-24  53cdb2fc8bc7dce0b6741e2150273451
# 2              2018-08-08  47770eb9100c2d0c44946d9cf07ec65d
# 3              2017-11-18  949d5b44dbf5de918fe9c16f97b45f8a
# 4              2018-02-13  ad21c59c0840e6cb83a9ceb5573f8159
# ...                   ...                               ...
# 99436          2017-03-09  9c5dedf39a927c1b2549525ed64a053c
# 99437          2018-02-06  63943bddc261676b46f01ca7ac2f7bd8
# 99438          2017-08-27  83c1379a015df1e13d02aae0204711ab
# 99439          2018-01-08  11c177c8e97725db2631073c19f07b62
# 99440          2018-03-08  66dea50a8b16d9b4dee7af250b4be1a5
#
#                             customer_id
# 0      06b8999e2fba1a1fbc88172c00ba8bc7
# 1      18955e83d337fd6b2def6b18a428ac77
# 2      4e7b3e00288586ebd08712fdd0374a03
# 3      b2b6027bc5c5109e529d4dc6358b12c3
# ...

# %%
type(dframe['Order_Date_Purchase'][0])
# Out:
# str

# %%
dframe['Order_Date_Purchase']=pd.to_datetime(dframe['Order_Date_Purchase'],errors='coerce',infer_datetime_format=True)

# %%
type(dframe['Order_Date_Purchase'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
dframe=dframe.set_index('Order_Date_Purchase')

dframe
# Out:
#                                              order_id  \
# Order_Date_Purchase
# 2017-10-02           e481f51cbdc54678b7cc49136f2d6af7
# 2018-07-24           53cdb2fc8bc7dce0b6741e2150273451
# 2018-08-08           47770eb9100c2d0c44946d9cf07ec65d
# 2017-11-18           949d5b44dbf5de918fe9c16f97b45f8a
# 2018-02-13           ad21c59c0840e6cb83a9ceb5573f8159
# ...                                               ...
# 2017-03-09           9c5dedf39a927c1b2549525ed64a053c
# 2018-02-06           63943bddc261676b46f01ca7ac2f7bd8
# 2017-08-27           83c1379a015df1e13d02aae0204711ab
# 2018-01-08           11c177c8e97725db2631073c19f07b62
# 2018-03-08           66dea50a8b16d9b4dee7af250b4be1a5
#
#                                           customer_id
# Order_Date_Purchase
# 2017-10-02           06b8999e2fba1a1fbc88172c00ba8bc7
# 2018-07-24           18955e83d337fd6b2def6b18a428ac77
# 2018-08-08           4e7b3e00288586ebd08712fdd0374a03
# ...

# %%
ord=dframe['order_id'].resample('D').count().to_frame()

# %%
ord['order_id'].sort_values(ascending=False)[:10]
# Out:
# Order_Date_Purchase
# 2017-11-24    1176
# 2017-11-25     499
# 2017-11-27     403
# 2017-11-26     391
# 2017-11-28     380
# 2018-08-06     372
# 2018-05-07     372
# 2018-08-07     370
# 2018-05-14     364
# 2018-05-16     357
# Name: order_id, dtype: int64

# %% [raw]
# data=df_ord2.merge(df_pay,on='index')
#
# data

# %%
dframe=data.loc[:,['order_purchase_timestamp','payment_value','order_status','payment_type']]

dframe
# Out:
#       order_purchase_timestamp  payment_value order_status payment_type
# 0          2017-10-02 10:56:33          99.33    delivered  credit_card
# 1          2018-07-24 20:41:37          24.39    delivered  credit_card
# 2          2018-08-08 08:38:49          65.71    delivered  credit_card
# 3          2017-11-18 19:28:06         107.78    delivered  credit_card
# 4          2018-02-13 21:18:39         128.45    delivered  credit_card
# ...                        ...            ...          ...          ...
# 99436      2017-03-09 09:54:05          43.70    delivered  credit_card
# 99437      2018-02-06 12:58:58          31.43    delivered       boleto
# 99438      2017-08-27 14:46:43          57.97    delivered       boleto
# 99439      2018-01-08 21:28:27          71.35    delivered  credit_card
# 99440      2018-03-08 20:57:30         139.52    delivered  credit_card
#
# [99441 rows x 4 columns]

# %%
dframe[['order_Date','Time']]=dframe['order_purchase_timestamp'].str.split(' ',expand=True)

# %%
dframe.head()
# Out:
#   order_purchase_timestamp  payment_value order_status payment_type  \
# 0      2017-10-02 10:56:33          99.33    delivered  credit_card
# 1      2018-07-24 20:41:37          24.39    delivered  credit_card
# 2      2018-08-08 08:38:49          65.71    delivered  credit_card
# 3      2017-11-18 19:28:06         107.78    delivered  credit_card
# 4      2018-02-13 21:18:39         128.45    delivered  credit_card
#
#    order_Date      Time
# 0  2017-10-02  10:56:33
# 1  2018-07-24  20:41:37
# 2  2018-08-08  08:38:49
# 3  2017-11-18  19:28:06
# 4  2018-02-13  21:18:39

# %%
#delting the unecessary columns

dframe=dframe.drop(['order_purchase_timestamp','Time'],axis=1)

dframe
# Out:
#        payment_value order_status payment_type  order_Date
# 0              99.33    delivered  credit_card  2017-10-02
# 1              24.39    delivered  credit_card  2018-07-24
# 2              65.71    delivered  credit_card  2018-08-08
# 3             107.78    delivered  credit_card  2017-11-18
# 4             128.45    delivered  credit_card  2018-02-13
# ...              ...          ...          ...         ...
# 99436          43.70    delivered  credit_card  2017-03-09
# 99437          31.43    delivered       boleto  2018-02-06
# 99438          57.97    delivered       boleto  2017-08-27
# 99439          71.35    delivered  credit_card  2018-01-08
# 99440         139.52    delivered  credit_card  2018-03-08
#
# [99441 rows x 4 columns]

# %%
dframe
# Out:
#             payment_value order_status payment_type
# order_Date
# 2017-10-02          99.33    delivered  credit_card
# 2018-07-24          24.39    delivered  credit_card
# 2018-08-08          65.71    delivered  credit_card
# 2017-11-18         107.78    delivered  credit_card
# 2018-02-13         128.45    delivered  credit_card
# ...                   ...          ...          ...
# 2017-03-09          43.70    delivered  credit_card
# 2018-02-06          31.43    delivered       boleto
# 2017-08-27          57.97    delivered       boleto
# 2018-01-08          71.35    delivered  credit_card
# 2018-03-08         139.52    delivered  credit_card
#
# [99441 rows x 3 columns]

# %%
dframe['order_Date']=pd.to_datetime(dframe['order_Date'])

# %%
dframe=dframe.set_index('order_Date')

# %%
#Daily Salees

dframe['payment_value'].resample('D').sum()
# Out:
# order_Date
# 2016-09-04    126.72
# 2016-09-05    206.44
# 2016-09-06      0.00
# 2016-09-07      0.00
# 2016-09-08      0.00
#                ...
# 2018-10-13      0.00
# 2018-10-14      0.00
# 2018-10-15      0.00
# 2018-10-16     87.82
# 2018-10-17     89.35
# Freq: D, Name: payment_value, Length: 774, dtype: float64

# %%
#Yearly Sales

dframe['payment_value'].resample('Y').sum()
# Out:
# order_Date
# 2016-12-31      53726.96
# 2017-12-31    6947529.12
# 2018-12-31    8341058.96
# Freq: A-DEC, Name: payment_value, dtype: float64

# %% [markdown]
# Payment installment Which means a regular scheduled payment made torwards a larger sum of money owed.

# %% [markdown]
# Recommedation:
#
#
#     The company should do better in Approval of items,carrier services and DeliveryGoods should not exceed more than the       maximum date
